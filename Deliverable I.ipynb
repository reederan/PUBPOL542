# %%
#load pandas

import pandas as pd

# %%
#read files

gitCloudRepo='https://github.com/Drops-of-Jupyter/PUBPOL542/raw/main/'
fileName1='distribution-human-rights-vdem.csv'
fileName2='infectious-disease-death-rates.csv'
fileName3='water-and-sanitation.csv'
humrightscsv=pd.read_csv(gitCloudRepo + fileName1)
infdeathscsv=pd.read_csv(gitCloudRepo + fileName2)
sanitationcsv=pd.read_csv(gitCloudRepo + fileName3)

# %%
# Human rights dataset
# Remove unneeded columns

humrightscsv.columns
bye=[1,4]
humrightscsv.drop(columns=humrightscsv.columns[bye],inplace=True)
humrightscsv.columns
# Out:
# Index(['Entity', 'Year', 'civ_libs_vdem_owid'], dtype='object')

# %%
# Filter rows to years 2015 - 2019

humrightscsv = humrightscsv[(humrightscsv['Year'] >= 2015) & (humrightscsv['Year'] <= 2019)]
humrightscsv.head()
# Out:
#           Entity  Year  civ_libs_vdem_owid
# 226  Afghanistan  2015               0.555
# 227  Afghanistan  2016               0.513
# 228  Afghanistan  2017               0.545
# 229  Afghanistan  2018               0.557
# 230  Afghanistan  2019               0.516

# %%
humrightscsv.columns.str.replace(pat="civ_libs_vdem_owid", 
                                 repl="VDEM", 
                                 regex=True)
humrightscsv.columns=humrightscsv.columns.str.replace("civ_libs_vdem_owid",
                                                      "VDEM",
                                                      regex=True)
humrightscsv.columns
# Out:
# Index(['Entity', 'Year', 'VDEM'], dtype='object')

# %%
humrightscsv.columns.str.replace(pat="Entity", 
                                 repl="Country", 
                                 regex=True)
humrightscsv.columns=humrightscsv.columns.str.replace("Entity",
                                                      "Country",
                                                      regex=True)

# %%
humrightscsv=humrightscsv.reset_index(drop=True)
humrightscsv.head()
# Out:
#        Country  Year   VDEM
# 0  Afghanistan  2015  0.555
# 1  Afghanistan  2016  0.513
# 2  Afghanistan  2017  0.545
# 3  Afghanistan  2018  0.557
# 4  Afghanistan  2019  0.516

# %%
humrightscsv.iloc[:,:2]
# Out:
#          Country  Year
# 0    Afghanistan  2015
# 1    Afghanistan  2016
# 2    Afghanistan  2017
# 3    Afghanistan  2018
# 4    Afghanistan  2019
# ..           ...   ...
# 925     Zimbabwe  2015
# 926     Zimbabwe  2016
# 927     Zimbabwe  2017
# 928     Zimbabwe  2018
# 929     Zimbabwe  2019
#
# [930 rows x 2 columns]

# %%
# Sanitations dataset
sanitationcsv.head()
# Out:
#    Access to improved drinking water  Access to basic drinking water  \
# 0                              31.83                           28.17
# 1                              31.86                           28.20
# 2                              34.19                           30.24
# 3                              36.51                           32.27
# 4                              38.85                           34.33
#
#    Access to limited drinking water  Access to unimproved drinking water  \
# 0                              3.66                                43.18
# 1                              3.66                                43.17
# 2                              3.95                                41.69
# 3                              4.24                                40.21
# 4                              4.52                                38.72
#
#    No access to drinking water  Access to safely managed drinking water  \
# 0                        24.99                                    10.93
# 1                        24.97                                    10.94
# 2                        24.12                                    11.73
# 3                        23.28                                    12.51
# 4                        22.42                                    13.31
#
#    Access to improved sanitation  Access to basic sanitation services  \
# 0                          27.52                                21.87
# 1                          27.54                                21.88
# 2                          29.27                                23.27
# 3                          31.01                                24.67
# 4                          32.76                                26.07
#
#    Access to limited sanitation services  \
# 0                                   5.65
# 1                                   5.66
# 2                                   6.00
# 3                                   6.34
# 4                                   6.69
#
#    Access to unimproved sanitation facilities  ...  wat_bas_without  \
# 0                                       46.68  ...            71.83
# 1                                       46.68  ...            71.80
# 2                                       45.74  ...            69.76
# 3                                       44.81  ...            67.73
# 4                                       43.87  ...            65.67
#
#    wat_sm_without  san_imp_number_without  san_bas_number_without  \
# 0           89.07              15061452.0              16235214.0
# 1           89.06              15656386.0              16879101.0
# 2           88.27              15984867.0              17340626.0
# 3           87.49              16338160.0              17839408.0
# 4           86.69              16627222.0              18281012.0
#
#    san_sm_number_without  san_imp_without  san_bas_without  san_sm_without  \
# 0                    NaN            72.48            78.13             NaN
# 1                    NaN            72.46            78.12             NaN
# 2                    NaN            70.73            76.73             NaN
# 3                    NaN            68.99            75.33             NaN
# 4                    NaN            67.24            73.93             NaN
#
#    hyg_bas_number_without  hyg_bas_without
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3                     NaN              NaN
# 4                     NaN              NaN
#
# [5 rows x 118 columns]

# %%
sanitationcsv = sanitationcsv[[
    'Entity',
    'Year',
    'Access to limited drinking water',
    'Access to limited sanitation services',
    'Access to limited handwashing facilities',
    'Number with access to limited drinking water',
    'Number with access to limited sanitation services',
    'Number with access to limited handwashing facilities',
]]

# %%
sanitationcsv.head()
# Out:
#         Entity  Year  Access to limited drinking water  \
# 0  Afghanistan  2000                              3.66
# 1  Afghanistan  2001                              3.66
# 2  Afghanistan  2002                              3.95
# 3  Afghanistan  2003                              4.24
# 4  Afghanistan  2004                              4.52
#
#    Access to limited sanitation services  \
# 0                                   5.65
# 1                                   5.66
# 2                                   6.00
# 3                                   6.34
# 4                                   6.69
#
#    Access to limited handwashing facilities  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Number with access to limited drinking water  \
# 0                                      760679.0
# 1                                      791149.0
# 2                                      892611.0
# 3                                     1003395.0
# 4                                     1118861.0
#
#    Number with access to limited sanitation services  \
# 0                                          1173762.0
# 1                                          1222714.0
# 2                                          1355759.0
# 3                                          1501247.0
# 4                                          1653789.0
#
#    Number with access to limited handwashing facilities
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
sanitationcsv = sanitationcsv[(sanitationcsv['Year'] >= 2015) & (sanitationcsv['Year'] <= 2019)]
sanitationcsv.head()
# Out:
#          Entity  Year  Access to limited drinking water  \
# 15  Afghanistan  2015                              3.51
# 16  Afghanistan  2016                              3.16
# 17  Afghanistan  2017                              2.78
# 18  Afghanistan  2018                              2.36
# 19  Afghanistan  2019                              1.91
#
#     Access to limited sanitation services  \
# 15                                   9.73
# 16                                   9.95
# 17                                  10.18
# 18                                  10.39
# 19                                  10.60
#
#     Access to limited handwashing facilities  \
# 15                                     34.41
# 16                                     34.38
# 17                                     34.34
# 18                                     34.31
# 19                                     34.27
#
#     Number with access to limited drinking water  \
# 15                                     1208330.0
# 16                                     1119152.0
# 17                                     1009170.0
# 18                                      878533.0
# 19                                      727415.0
#
#     Number with access to limited sanitation services  \
# 15                                          3347876.0
# 16                                          3522325.0
# 17                                          3693515.0
# 18                                          3862932.0
# 19                                          4033366.0
#
#     Number with access to limited handwashing facilities
# 15                                         11842501.0
# 16                                         12164369.0
# 17                                         12465522.0
# 18                                         12752395.0
# 19                                         13035749.0

# %%
sanitationcsv=sanitationcsv.reset_index(drop=True)
sanitationcsv.head()
# Out:
#         Entity  Year  Access to limited drinking water  \
# 0  Afghanistan  2015                              3.51
# 1  Afghanistan  2016                              3.16
# 2  Afghanistan  2017                              2.78
# 3  Afghanistan  2018                              2.36
# 4  Afghanistan  2019                              1.91
#
#    Access to limited sanitation services  \
# 0                                   9.73
# 1                                   9.95
# 2                                  10.18
# 3                                  10.39
# 4                                  10.60
#
#    Access to limited handwashing facilities  \
# 0                                     34.41
# 1                                     34.38
# 2                                     34.34
# 3                                     34.31
# 4                                     34.27
#
#    Number with access to limited drinking water  \
# 0                                     1208330.0
# 1                                     1119152.0
# 2                                     1009170.0
# 3                                      878533.0
# 4                                      727415.0
#
#    Number with access to limited sanitation services  \
# 0                                          3347876.0
# 1                                          3522325.0
# 2                                          3693515.0
# 3                                          3862932.0
# 4                                          4033366.0
#
#    Number with access to limited handwashing facilities
# 0                                         11842501.0
# 1                                         12164369.0
# 2                                         12465522.0
# 3                                         12752395.0
# 4                                         13035749.0

# %%
sanitationcsv.columns.str.replace(pat="Access to limited drinking water", 
                                  repl="LDW", 
                                  regex=True)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Access to limited drinking water",
                                                        "LDW",
                                                        regex=True)

# %%
sanitationcsv.columns.str.replace(pat="Access to limited sanitation services", 
                                  repl="LSS", 
                                  regex=True)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Access to limited sanitation services",
                                                        "LSS",
                                                        regex=True)

# %%
sanitationcsv.columns.str.replace(pat="Access to limited handwashing facilities", 
                                  repl="LHF", 
                                  regex=True)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Access to limited handwashing facilities",
                                                        "LHF",
                                                        regex=True)

# %%
sanitationcsv.columns.str.replace(pat="Number with access to limited drinking water", 
                                  repl="#LDW", 
                                  regex=True)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Number with access to limited drinking water",
                                                        "#LDW",
                                                        regex=True)

# %%
sanitationcsv.columns.str.replace(pat="Number with access to limited sanitation services", 
                                  repl="#LSS", 
                                  regex=True)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Number with access to limited sanitation services",
                                                        "#LSS",
                                                        regex=True)

# %%
sanitationcsv.columns.str.replace(pat="Number with access to limited handwashing facilities", 
                                  repl="#LHF", 
                                  regex=True)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Number with access to limited handwashing facilities",
                                                        "#LHF",
                                                        regex=True)

# %%
sanitationcsv.columns.str.replace(pat="Entity", 
                                  repl="Country", 
                                  regex=True)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Entity",
                                                        "Country",
                                                        regex=True)

# %%
sanitationcsv.head()
# Out:
#        Country  Year   LDW    LSS    LHF       #LDW       #LSS        #LHF
# 0  Afghanistan  2015  3.51   9.73  34.41  1208330.0  3347876.0  11842501.0
# 1  Afghanistan  2016  3.16   9.95  34.38  1119152.0  3522325.0  12164369.0
# 2  Afghanistan  2017  2.78  10.18  34.34  1009170.0  3693515.0  12465522.0
# 3  Afghanistan  2018  2.36  10.39  34.31   878533.0  3862932.0  12752395.0
# 4  Afghanistan  2019  1.91  10.60  34.27   727415.0  4033366.0  13035749.0

# %%
sanitationcsv.iloc[:,:2]
# Out:
#           Country  Year
# 0     Afghanistan  2015
# 1     Afghanistan  2016
# 2     Afghanistan  2017
# 3     Afghanistan  2018
# 4     Afghanistan  2019
# ...           ...   ...
# 1206     Zimbabwe  2015
# 1207     Zimbabwe  2016
# 1208     Zimbabwe  2017
# 1209     Zimbabwe  2018
# 1210     Zimbabwe  2019
#
# [1211 rows x 2 columns]

# %%
infdeathscsv.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)
# 0                                             394.42
# 1                                             368.78
# 2                                             346.83
# 3                                             350.51
# 4                                             361.07

# %%
infdeathscsv = infdeathscsv[(infdeathscsv['Year'] >= 2015) & (infdeathscsv['Year'] <= 2019)]
infdeathscsv.head()
# Out:
#          Entity Code  Year  \
# 25  Afghanistan  AFG  2015
# 26  Afghanistan  AFG  2016
# 27  Afghanistan  AFG  2017
# 28  Afghanistan  AFG  2018
# 29  Afghanistan  AFG  2019
#
#     Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)
# 25                                             164.90
# 26                                             158.93
# 27                                             152.43
# 28                                             146.83
# 29                                             140.37

# %%
infdeathscsv.columns
bye=[1]
infdeathscsv.drop(columns=infdeathscsv.columns[bye],inplace=True)
infdeathscsv.columns
# Out:
# Index(['Entity', 'Year',
#        'Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)'],
#       dtype='object')

# %%
infdeathscsv.columns.str.replace(pat="Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)", 
                                 repl="Death Rate", 
                                 regex=True)
infdeathscsv.columns=infdeathscsv.columns.str.replace("Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)",
                                                      "Death Rate",
                                                      regex=True)

# %%
infdeathscsv.columns.str.replace(pat="Entity", 
                                 repl="Country", 
                                 regex=True)
infdeathscsv.columns=infdeathscsv.columns.str.replace("Entity",
                                                      "Country",
                                                      regex=True)

# %%
infdeathscsv.columns
# Out:
# Index(['Country', 'Year',
#        'Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)'],
#       dtype='object')

# %%
infdeathscsv=infdeathscsv.reset_index(drop=True)
infdeathscsv.head()
# Out:
#        Country  Year  \
# 0  Afghanistan  2015
# 1  Afghanistan  2016
# 2  Afghanistan  2017
# 3  Afghanistan  2018
# 4  Afghanistan  2019
#
#    Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)
# 0                                             164.90
# 1                                             158.93
# 2                                             152.43
# 3                                             146.83
# 4                                             140.37

# %%
" Afghanistan ".strip()
# Out:
# 'Afghanistan'

# %%
infdeathscsv.iloc[:,:2]
# Out:
#           Country  Year
# 0     Afghanistan  2015
# 1     Afghanistan  2016
# 2     Afghanistan  2017
# 3     Afghanistan  2018
# 4     Afghanistan  2019
# ...           ...   ...
# 1135     Zimbabwe  2015
# 1136     Zimbabwe  2016
# 1137     Zimbabwe  2017
# 1138     Zimbabwe  2018
# 1139     Zimbabwe  2019
#
# [1140 rows x 2 columns]

# %%
sanitationcsv.iloc[:,:2]
# Out:
#           Country  Year
# 0     Afghanistan  2015
# 1     Afghanistan  2016
# 2     Afghanistan  2017
# 3     Afghanistan  2018
# 4     Afghanistan  2019
# ...           ...   ...
# 1206     Zimbabwe  2015
# 1207     Zimbabwe  2016
# 1208     Zimbabwe  2017
# 1209     Zimbabwe  2018
# 1210     Zimbabwe  2019
#
# [1211 rows x 2 columns]

# %%
infdeathscsv.iloc[:,1]
# Out:
# 0       2015
# 1       2016
# 2       2017
# 3       2018
# 4       2019
#         ...
# 1135    2015
# 1136    2016
# 1137    2017
# 1138    2018
# 1139    2019
# Name: Year, Length: 1140, dtype: int64

# %%
infdeathscsv.Year.value_counts()
# Out:
# 2015    228
# 2016    228
# 2017    228
# 2018    228
# 2019    228
# Name: Year, dtype: int64

# %%
infdeathscsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1140 entries, 0 to 1139
# Data columns (total 3 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Country                                                                         1140 non-null   object
#  1   Year                                                                            1140 non-null   int64
#  2   Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)  1140 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 26.8+ KB

# %%
sanitationcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  1211 non-null   object
#  1   Year     1211 non-null   int64
#  2   LDW      1203 non-null   float64
#  3   LSS      1182 non-null   float64
#  4   LHF      507 non-null    float64
#  5   #LDW     1118 non-null   float64
#  6   #LSS     1097 non-null   float64
#  7   #LHF     452 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 75.8+ KB

# %%
humrightscsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Entity  930 non-null    object
#  1   Year    930 non-null    int64
#  2   VDEM    930 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 21.9+ KB
